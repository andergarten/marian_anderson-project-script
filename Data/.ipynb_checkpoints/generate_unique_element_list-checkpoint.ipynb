# %%
import pandas as pd
import os
import numpy
from openpyxl import *

# %%
os.chdir(r'/Users/zhiyuzhou/OneDrive/Penn/Work_on-campus/Marian_Anderson/Descriptive_matadata')
data = pd.read_excel("test_data_178-179_4.3.19.xlsx")
#data.head(200)
# Out:
#                    ARK ID     Call No.     BOX     FOLDER  Unnamed: 4  \
# 0                     NaN           NaN  178.0  8516-8543         NaN
# 1    ark:/81431/p3xp6v580  Ms. Coll 200  178.0       8516         1.0
# 2    ark:/81431/p3sx64c47  Ms. Coll 200  178.0       8517         1.0
# 3    ark:/81431/p3p55dk0d  Ms. Coll 200  178.0       8517         2.0
# 4    ark:/81431/p3jd4pr6n  Ms. Coll 200  178.0       8518         1.0
# 5    ark:/81431/p3dn3zz11  Ms. Coll 200  178.0       8518         2.0
# 6    ark:/81431/p38w38472  Ms. Coll 200  178.0       8519         1.0
# 7    ark:/81431/p35717q71  Ms. Coll 200  178.0       8519         2.0
# 8    ark:/81431/p31g0hx3w  Ms. Coll 200  178.0       8520         1.0
# 9    ark:/81431/p3wp9t88r  Ms. Coll 200  178.0       8520         2.0
# 10   ark:/81431/p3rx93g40  Ms. Coll 200  178.0       8520         3.0
# 11   ark:/81431/p3n58cp05  Ms. Coll 200  178.0       8520         4.0
# 12   ark:/81431/p3hd7nv6d  Ms. Coll 200  178.0       8520         5.0
# 13   ark:/81431/p3cn6z22p  Ms. Coll 200  178.0       8521         1.0
# 14   ark:/81431/p3804xn15  Ms. Coll 200  178.0       8521         2.0
# 15   ark:/81431/p34746t7s  Ms. Coll 200  178.0       8521         3.0
# 16   ark:/81431/p30g3h132  Ms. Coll 200  178.0       8521         4.0
# 17   ark:/81431/p3vq2sc82  Ms. Coll 200  178.0       8521         5.0
# 18   ark:/81431/p3qz22k49  Ms. Coll 200  178.0       8522         1.0
# 19   ark:/81431/p3m61bs1z  Ms. Coll 200  178.0       8522         2.0
# 20   ark:/81431/p3gf0mz76  Ms. Coll 200  178.0       8522         3.0
# 21   ark:/81431/p3br8mj48  Ms. Coll 200  178.0       8523         1.0
# 22   ark:/81431/p3707wr0f  Ms. Coll 200  178.0       8523         2.0
# 23   ark:/81431/p33775x62  Ms. Coll 200  178.0       8523         3.0
# 24   ark:/81431/p3zg6g913  Ms. Coll 200  178.0       8523         4.0
# 25   ark:/81431/p3tq5rg7b  Ms. Coll 200  178.0       8524         1.0
# 26   ark:/81431/p3pz51p42  Ms. Coll 200  178.0       8524         2.0
# 27   ark:/81431/p3k649w07  Ms. Coll 200  178.0       8524         3.0
# 28   ark:/81431/p3fj29f96  Ms. Coll 200  178.0       8524         4.0
# 29   ark:/81431/p39s1kn52  Ms. Coll 200  178.0       8525         1.0
# ..                    ...           ...    ...        ...         ...
# 165  ark:/81431/p30p0wt0d  Ms. Coll 200  179.0       8548         9.0
# 166  ark:/81431/p3vx06556  Ms. Coll 200  179.0       8548        10.0
# 167  ark:/81431/p3r785r44  Ms. Coll 200  179.0       8549         1.0
# 168  ark:/81431/p3mg7fz1g  Ms. Coll 200  179.0       8549         2.0
# 169  ark:/81431/p3gq6r474  Ms. Coll 200  179.0       8549         3.0
# 170  ark:/81431/p3bz61b3c  Ms. Coll 200  179.0       8549         4.0
# 171  ark:/81431/p37659h9x  Ms. Coll 200  179.0       8549         5.0
# 172  ark:/81431/p33f4kq5s  Ms. Coll 200  179.0       8549         6.0
# 173  ark:/81431/p3zp3w30t  Ms. Coll 200  179.0       8550         1.0
# 174  ark:/81431/p3v11vn7q  Ms. Coll 200  179.0       8550         2.0
# 175  ark:/81431/p3q814v4f  Ms. Coll 200  179.0       8550         3.0
# 176  ark:/81431/p3kh0f20q  Ms. Coll 200  179.0       8550         4.0
# 177  ark:/81431/p3fq9q76d  Ms. Coll 200  179.0       8550         5.0
# 178  ark:/81431/p39z90f2n  Ms. Coll 200  179.0       8550         6.0
# 179  ark:/81431/p36688m86  Ms. Coll 200  179.0       8551         1.0
# 180  ark:/81431/p32f7jt42  Ms. Coll 200  179.0       8551         2.0
# 181  ark:/81431/p3xs5jk2d  Ms. Coll 200  179.0       8551         3.0
# 182  ark:/81431/p3t14tr8z  Ms. Coll 200  179.0       8551         4.0
# 183  ark:/81431/p3p843z3q  Ms. Coll 200  179.0       8552         1.0
# 184  ark:/81431/p3jh3d49c  Ms. Coll 200  179.0       8552         2.0
# 185  ark:/81431/p3dr2pb6q  Ms. Coll 200  179.0       8552         3.0
# 186  ark:/81431/p3901zj2w  Ms. Coll 200  179.0       8552         4.0
# 187  ark:/81431/p35717q8h  Ms. Coll 200  179.0       8552         5.0
# 188  ark:/81431/p31j97981  Ms. Coll 200  179.0       8552         6.0
# 189  ark:/81431/p3ws8hp3n  Ms. Coll 200  179.0       8552         7.0
# 190  ark:/81431/p3s17sv8q  Ms. Coll 200  179.0       8553         1.0
# 191  ark:/81431/p3n87324c  Ms. Coll 200  179.0       8553         2.0
# 192  ark:/81431/p3hh6c807  Ms. Coll 200  179.0       8553         3.0
# 193  ark:/81431/p3cr5nf6g  Ms. Coll 200  179.0       8553         4.0
# 194  ark:/81431/p3804xn2n  Ms. Coll 200  179.0       8553         5.0
#
#                                                   ITEM  LABEL  \
# 0                                  1916-1935 December.    NaN
# 1                              Programs: 1916, April 6    NaN
# 2          Programs: 1919, December 5 / 1919, March 18    NaN
# 3          Programs: 1919, December 5 / 1919, March 18    NaN
# 4    Programs: 1921, April 23 / 20 June 1921 [H.S. ...    NaN
# 5    Programs: 1921, April 23 / 20 June 1921 [H.S. ...    NaN
# 6        Programs: 1923, February 17 to 1923, March 14    NaN
# 7        Programs: 1923, February 17 to 1923, March 14    NaN
# 8      Programs: 1924, January 16 to 1924, December 10    NaN
# 9      Programs: 1924, January 16 to 1924, December 10    NaN
# 10     Programs: 1924, January 16 to 1924, December 10    NaN
# 11     Programs: 1924, January 16 to 1924, December 10    NaN
# 12     Programs: 1924, January 16 to 1924, December 10    NaN
# 13          Programs: 1925, January 22 to 1925, May 21    NaN
# 14          Programs: 1925, January 22 to 1925, May 21    NaN
# 15          Programs: 1925, January 22 to 1925, May 21    NaN
# 16          Programs: 1925, January 22 to 1925, May 21    NaN
# 17          Programs: 1925, January 22 to 1925, May 21    NaN
# 18       Programs: 1925, August 26 to 1925, December 5    NaN
# 19       Programs: 1925, August 26 to 1925, December 5    NaN
# 20       Programs: 1925, August 26 to 1925, December 5    NaN
# 21            Programs: 1926, April 11 to 1926, May 20    NaN
# 22            Programs: 1926, April 11 to 1926, May 20    NaN
# 23            Programs: 1926, April 11 to 1926, May 20    NaN
# 24            Programs: 1926, April 11 to 1926, May 20    NaN
# 25          Programs: 1927, January 28 to 1927, May 20    NaN
# 26          Programs: 1927, January 28 to 1927, May 20    NaN
# 27          Programs: 1927, January 28 to 1927, May 20    NaN
# 28          Programs: 1927, January 28 to 1927, May 20    NaN
# 29        Programs: 1928, June 15 to 1928, December 30    NaN
# ..                                                 ...    ...
# 165    Programs: 1937, January 26 to 1937, February 24    NaN
# 166    Programs: 1937, January 26 to 1937, February 24    NaN
# 167    Programs: 1936, November 4 to 1936, December 06    NaN
# 168    Programs: 1936, November 4 to 1936, December 06    NaN
# 169    Programs: 1936, November 4 to 1936, December 06    NaN
# 170    Programs: 1936, November 4 to 1936, December 06    NaN
# 171    Programs: 1936, November 4 to 1936, December 06    NaN
# 172    Programs: 1936, November 4 to 1936, December 06    NaN
# 173          Programs: 1937, March 2 to 1937, March 29    NaN
# 174          Programs: 1937, March 2 to 1937, March 29    NaN
# 175          Programs: 1937, March 2 to 1937, March 29    NaN
# 176          Programs: 1937, March 2 to 1937, March 29    NaN
# 177          Programs: 1937, March 2 to 1937, March 29    NaN
# 178          Programs: 1937, March 2 to 1937, March 29    NaN
# 179          Programs: 1937, April 2 to 1937, April 15    NaN
# 180          Programs: 1937, April 2 to 1937, April 15    NaN
# 181          Programs: 1937, April 2 to 1937, April 15    NaN
# 182          Programs: 1937, April 2 to 1937, April 15    NaN
# 183              Programs: 1937, May 8 to 1937, July 7    NaN
# 184              Programs: 1937, May 8 to 1937, July 7    NaN
# 185              Programs: 1937, May 8 to 1937, July 7    NaN
# 186              Programs: 1937, May 8 to 1937, July 7    NaN
# 187              Programs: 1937, May 8 to 1937, July 7    NaN
# 188              Programs: 1937, May 8 to 1937, July 7    NaN
# 189              Programs: 1937, May 8 to 1937, July 7    NaN
# 190              1937, November 5 to 1937, November 28    NaN
# 191              1937, November 5 to 1937, November 28    NaN
# 192              1937, November 5 to 1937, November 28    NaN
# 193              1937, November 5 to 1937, November 28    NaN
# 194              1937, November 5 to 1937, November 28    NaN
#
#                                                  VENUE            CITY STATE  \
# 0                                                  NaN             NaN   NaN
# 1                                    Musical Fund Hall    Philadelphia    PA
# 2                                    Musical Fund Hall    Philadelphia    PA
# 3                                     Academy of Music    Philadelphia    PA
# 4                                  Carnegie Music Hall        Duquesne    PA
# 5             South Philadelphia HIgh School for Girls    Philadelphia    PA
# 6                                     Academy of Music    Philadelphia    PA
# 7                                  1710 Chesnut Street    Philadelphia    PA
# 8                                      Lincoln Theatre    [Washington]  [DC]
# 9                           Carmel Presbyterian Church    [Cincinnati]  [OH]
# 10                                    Renaissance Hall      [New York]  [NY]
# 11                                       The Town Hall        New York    NY
# 12                    William Penn Evening High School    Philadelphia    PA
# 13                           P. O. S. of A. Auditorium        Riverton    NJ
# 14                                  Central Auditorium             NaN   NaN
# 15                                        Trinity Hall      Norristown    PA
# 16                                     Orpheum Theatre             NaN   NaN
# 17                          Germantown YMCA Auditorium    Philadelphia    PA
# 18                              Lewisohn Stadium, CCNY        New York    NY
# 19                         First Congregational Church      Washington    DC
# 20                       Ogden Hall, Hampton Institute         Hampton    VA
# 21                                     NCR Schoolhouse        [Dayton]  [OH]
# 22                                    Academy of Music    Philadelphia    PA
# 23                                    Academy of Music    Philadelphia    PA
# 24                                    Academy of Music    Philadelphia    PA
# 25             Murphy Hall, North Carolina A&T College      Greensboro    NC
# 26                          Florida A&M College Chapel     Tallahassee    FL
# 27                                 Lincoln High School     Jersey City    NJ
# 28                                   LaFayette Theatre    Fayetteville    NC
# 29                                        Wigmore Hall          London   NaN
# ..                                                 ...             ...   ...
# 165  Cyrus Northop Memorial Auditorium, University ...     Minneapolis    MN
# 166                                      Symphony Hall          Boston    MA
# 167      Grande Salle de la Société Royale de Zoologie         Antwerp   NaN
# 168                                      Maison Gaveau           Paris   NaN
# 169                                       Queen's Hall          London   NaN
# 170                            Salle de la Réformation          Geneva   NaN
# 171                      Grosser Saal, Tonhalle Zürich          Zürich   NaN
# 172                            Großer Konzerthaus-Saal               ?   NaN
# 173                           War Memorial Opera House   San Francisco    CA
# 174                     The Oakland Auditorium Theatre         Oakland    CA
# 175                                Winnipeg Auditorium        Winnipeg   NaN
# 176                            Philharmonic Auditorium     Los Angeles    CA
# 177                           War Memorial Opera House   San Francisco    CA
# 178                                    Hill Auditorium       Ann Arbor    MI
# 179                                      Carnegie Hall        New York    NY
# 180                                      Carnegie Hall        New York    NY
# 181                                   Academy of Music    Philadelphia    PA
# 182                              Montclair High School       Montclair    NJ
# 183                                   Academy of Music    Philadelphia    PA
# 184                                   Academy of Music    Philadelphia    PA
# 185                                      Carnegie Hall        New York    NY
# 186                                  Theatro Municipal  Rio de Janeiro   NaN
# 187                                  Theatro Municipal  Rio de Janeiro   NaN
# 188                                  Theatro Municipal  Rio de Janeiro   NaN
# 189                                       Teatro Solis      Montevideo   NaN
# 190                                       Queen's Hall          London   NaN
# 191                                       Queen's Hall          London   NaN
# 192                          Groote Feestzaal Zoologie         Antwerp   NaN
# 193                                 Fővárosi Vigadóban        Budapest   NaN
# 194                                 Fővárosi Vigadóban        Budapest   NaN
#
#          COUNTRY       DATE (MM/DD/YYYY)  \
# 0            NaN                     NaN
# 1            USA              04/06/1916
# 2            USA              12/05/1919
# 3            USA              03/18/1920
# 4            USA              04/23/1921
# 5            USA              06/20/1921
# 6            USA              02/17/1923
# 7            USA              03/14/1923
# 8            USA              01/16/1924
# 9            USA              02/14/1924
# 10           USA              02/18/1924
# 11           USA              04/25/1924
# 12           USA              12/10/1924
# 13           USA              01/22/1925
# 14           USA              02/13/1925
# 15           USA              03/05/1925
# 16           USA              03/24/1925
# 17           USA              05/21/1925
# 18           USA              08/26/1925
# 19           USA              11/10/1926
# 20           USA              12/05/1925
# 21           USA              04/11/1926
# 22           USA              05/20/1926
# 23           USA              05/20/1926
# 24           USA              05/20/1926
# 25           USA              01/14/1927
# 26           USA              01/28/1927
# 27           USA              02/25/1927
# 28           USA              05/20/1927
# 29            UK              06/15/1928
# ..           ...                     ...
# 165          USA              02/04/1937
# 166          USA              01/31/1937
# 167      Belgium              11/04/1936
# 168       France              11/12/1936
# 169      England              11/17/1936
# 170  Switzerland              11/23/1936
# 171  Switzerland              11/25/1936
# 172  Switzerland              12/06/1936
# 173          USA  03/05/1937; 05/06/1937
# 174          USA              03/08/1937
# 175       Canada              03/15/1937
# 176          USA              03/02/1937
# 177          USA              02/24/1937
# 178          USA              03/29/1937
# 179          USA              04/02/1937
# 180          USA              04/02/1937
# 181          USA              04/05/1937
# 182          USA              04/15/1937
# 183          USA              05/08/1937
# 184          USA              05/08/1937
# 185          USA              05/12/1937
# 186       Brazil              05/31/1937
# 187       Brazil              06/02/1937
# 188       Brazil              06/05/1937
# 189      Uruguay              07/07/1937
# 190      England              11/05/1937
# 191      England              11/05/1937
# 192      Belgium              11/15/1937
# 193      Hungary              11/28/1937
# 194      Hungary              11/28/1937
#
#      No. of leaves/pages (including the front and back covers, inside front and back covers, and blank leaves)  \
# 0                                                  NaN
# 1                                                  4.0
# 2                                                  8.0
# 3                                                 20.0
# 4                                                  8.0
# 5                                                  8.0
# 6                                                  4.0
# 7                                                  2.0
# 8                                                  4.0
# 9                                                 16.0
# 10                                                 2.0
# 11                                                16.0
# 12                                                 4.0
# 13                                                 2.0
# 14                                                 4.0
# 15                                                 2.0
# 16                                                 4.0
# 17                                                 4.0
# 18                                                32.0
# 19                                                 4.0
# 20                                                 4.0
# 21                                                 4.0
# 22                                                 2.0
# 23                                                 2.0
# 24                                                 4.0
# 25                                                 4.0
# 26                                                 2.0
# 27                                                 2.0
# 28                                                 4.0
# 29                                                 8.0
# ..                                                 ...
# 165                                               20.0
# 166                                                NaN
# 167                                               12.0
# 168                                               16.0
# 169                                               16.0
# 170                                                4.0
# 171                                                4.0
# 172                                                2.0
# 173                                               24.0
# 174                                                4.0
# 175                                               14.0
# 176                                               38.0
# 177                                               28.0
# 178                                                2.0
# 179                                               16.0
# 180                                               16.0
# 181                                                4.0
# 182                                               20.0
# 183                                                4.0
# 184                                                4.0
# 185                                               16.0
# 186                                                8.0
# 187                                                6.0
# 188                                                2.0
# 189                                                8.0
# 190                                               30.0
# 191                                               28.0
# 192                                               12.0
# 193                                                8.0
# 194                                               10.0
#
#                                       Notes (optional)  QA Pass?  QA Fail?  \
# 0                                                  NaN       NaN       NaN
# 1    fragile; William King and Blanche Poole, accom...       NaN       NaN
# 2    note says this is a photocopy and that origina...       NaN       NaN
# 3    fragile; leaves are unbound and each is in sep...       NaN       NaN
# 4                                                  NaN       NaN       NaN
# 5    photocopy; original at library company of phil...       NaN       NaN
# 6    fragile; two signatures, with notes saying tha...       NaN       NaN
# 7                                                  NaN       NaN       NaN
# 8    lots of handwriting/annotation on p.2 (concert...       NaN       NaN
# 9                                                  NaN       NaN       NaN
# 10                                             fragile       NaN       NaN
# 11                                                 NaN       NaN       NaN
# 12                                                 NaN       NaN       NaN
# 13                                   King, accompanist       NaN       NaN
# 14                                   King, accompanist       NaN       NaN
# 15                                   King, accompanist       NaN       NaN
# 16                    with Howard Univ. Choral Society       NaN       NaN
# 17                                   king, accompanist       NaN       NaN
# 18                                   king, accompanist       NaN       NaN
# 19                                                 NaN       NaN       NaN
# 20                                                 NaN       NaN       NaN
# 21                                   king, accompanist       NaN       NaN
# 22      Note from "Marian Anderson management" on back       NaN       NaN
# 23           Duplicate of 8523 #2, without hanswriting       NaN       NaN
# 24   Same concert as 8523#s 2&3, different program;...       NaN       NaN
# 25                                                 NaN       NaN       NaN
# 26            handwriting on back cover (song request)       NaN       NaN
# 27                                                 NaN       NaN       NaN
# 28                                                 NaN       NaN       NaN
# 29                                                 NaN       NaN       NaN
# ..                                                 ...       ...       ...
# 165                                                NaN       NaN       NaN
# 166                                                NaN       NaN       NaN
# 167                                                NaN       NaN       NaN
# 168                                                NaN       NaN       NaN
# 169                                                NaN       NaN       NaN
# 170                                tear on top portion       NaN       NaN
# 171                                 small tear on side       NaN       NaN
# 172  in plastic cover- appears to be a photocopy, l...       NaN       NaN
# 173                                                NaN       NaN       NaN
# 174  cursive handwriting on back cover- partially d...       NaN       NaN
# 175  page count includes inserted advertisement for...       NaN       NaN
# 176                  page count includes insert (2pgs)       NaN       NaN
# 177               duplicate of 8548 #4 in wrong folder       NaN       NaN
# 178                               light surface stains       NaN       NaN
# 179  autograph on front cover made out to "Miss Mar...       NaN       NaN
# 180             duplicate of 8551 #1 with no autograph       NaN       NaN
# 181                                                NaN       NaN       NaN
# 182                                                NaN       NaN       NaN
# 183      name and addresses handwritten on front cover       NaN       NaN
# 184               duplicate of 8552 #1, no handwriting       NaN       NaN
# 185                                                NaN       NaN       NaN
# 186  4 page program includes 4 page insert of song ...       NaN       NaN
# 187          tri-fold, center page missing top section       NaN       NaN
# 188                                            bi-fold       NaN       NaN
# 189                                                NaN       NaN       NaN
# 190  many pages have sections of text cut out, smal...       NaN       NaN
# 191  duplicate of 8553 #1 but includes missing sect...       NaN       NaN
# 192                                                NaN       NaN       NaN
# 193                                                NaN       NaN       NaN
# 194  Duplicate of 8553 #4, includes 2 page insert o...       NaN       NaN
#
#      QA Fail reason
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN
# 6               NaN
# 7               NaN
# 8               NaN
# 9               NaN
# 10              NaN
# 11              NaN
# 12              NaN
# 13              NaN
# 14              NaN
# 15              NaN
# 16              NaN
# 17              NaN
# 18              NaN
# 19              NaN
# 20              NaN
# 21              NaN
# 22              NaN
# 23              NaN
# 24              NaN
# 25              NaN
# 26              NaN
# 27              NaN
# 28              NaN
# 29              NaN
# ..              ...
# 165             NaN
# 166             NaN
# 167             NaN
# 168             NaN
# 169             NaN
# 170             NaN
# 171             NaN
# 172             NaN
# 173             NaN
# 174             NaN
# 175             NaN
# 176             NaN
# 177             NaN
# 178             NaN
# 179             NaN
# 180             NaN
# 181             NaN
# 182             NaN
# 183             NaN
# 184             NaN
# 185             NaN
# 186             NaN
# 187             NaN
# 188             NaN
# 189             NaN
# 190             NaN
# 191             NaN
# 192             NaN
# 193             NaN
# 194             NaN
#
# [195 rows x 17 columns]

# %% [markdown]
# # Find unique value in all fields

# %%
# get unique city
city = data['CITY'].unique()
# get unique state
state = data['STATE'].unique()
# get unique country
country = data['COUNTRY'].unique()
# get unique venue
venue = data['VENUE'].unique()
# get uniqie date
date = data['DATE (MM/DD/YYYY)'].unique()
# create a dict to store the unique information
uniq_dict = dict(City = city, State = state, Country = country, Venue = venue, Date = date)
# create a dataframe to store the data
uniq_list = pd.DataFrame(dict((k, pd.Series(v)) for k,v in uniq_dict.items()))

# %% [markdown]
# # Write all unique value to a new sheet

# %%
# create a new writer
writer = pd.ExcelWriter("uniq_element_list_178-179_4.3.19.xlsx", engine='openpyxl')
# open a workbook
wb = load_workbook('uniq_element_list_178-179_4.3.19.xlsx')
ws = wb['Sheet2']
# specify writer's workbook and worksheet
writer.book = wb
writer.sheet = ws

# write data to excel
for index, row in uniq_list.iterrows():
    # write header
    #ws.cell(row = index + 1, column = 3*col + 1).value
    for col in range(0,5):
        ws.cell(row = index + 1, column = 3*col + 1).value = row[col]   
        
# save
wb.save('uniq_element_list_178-179_4.3.19.xlsx')
